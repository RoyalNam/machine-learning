# %%
col_name = ['Sex', 'Length', 'Diameter', 'Height', 'Whole_weight', 'Shucked_weight', 'Viscera_weight', 'Shell_weight', 'Rings']

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
data = pd.read_csv('abalone.data', names=col_name)
data
# Out:
#      Sex  Length  Diameter  Height  Whole_weight  Shucked_weight
# 0      M   0.455     0.365   0.095        0.5140          0.2245  \
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera_weight  Shell_weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
data.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole_weight      0
# Shucked_weight    0
# Viscera_weight    0
# Shell_weight      0
# Rings             0
# dtype: int64

# %%
X = data.drop('Rings', axis=1)
y = data.Rings

# %%
from sklearn.preprocessing import OneHotEncoder
encode = OneHotEncoder(handle_unknown='ignore', sparse=False)
sex_transform_df = pd.DataFrame(encode.fit_transform(X[['Sex']]), columns=encode.get_feature_names_out(['Sex']))
sex_transform_df


X = pd.concat([X, sex_transform_df], axis=1)
X.drop('Sex', axis=1, inplace=True)
X
# Out:
# C:\Users\DELL INSPIRON 5625\AppData\Roaming\Python\Python311\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
#       Length  Diameter  Height  Whole_weight  Shucked_weight  Viscera_weight
# 0      0.455     0.365   0.095        0.5140          0.2245          0.1010  \
# 1      0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2      0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3      0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4      0.330     0.255   0.080        0.2050          0.0895          0.0395
# ...      ...       ...     ...           ...             ...             ...
# 4172   0.565     0.450   0.165        0.8870          0.3700          0.2390
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, test_size=0.2)

# %%
y_test
# Out:
# 668     13
# 1580     8
# 3784    11
# 463      5
# 2615    12
#         ..
# 575     11
# 3231    12
# 1084     7
# 290     17
# 2713     4
# Name: Rings, Length: 836, dtype: int64

# %%
X_train
# Out:
#       Length  Diameter  Height  Whole_weight  Shucked_weight  Viscera_weight
# 3141   0.180     0.135   0.080        0.0330          0.0145          0.0070  \
# 3521   0.215     0.150   0.055        0.0410          0.0150          0.0090
# 883    0.660     0.530   0.170        1.3905          0.5905          0.2120
# 3627   0.715     0.525   0.200        1.8900          0.9500          0.4360
# 2106   0.595     0.455   0.155        1.0410          0.4160          0.2105
# ...      ...       ...     ...           ...             ...             ...
# 1033   0.650     0.525   0.185        1.6220          0.6645          0.3225
# 3264   0.655     0.500   0.140        1.1705          0.5405          0.3175
# 1653   0.595     0.450   0.145        0.9590          0.4630          0.2065
# 2607   0.625     0.490   0.165        1.1270          0.4770          0.2365
# 2732   0.410     0.325   0.110        0.3260          0.1325          0.0750
#
#       Shell_weight  Sex_F  Sex_I  Sex_M
# ...

# %%
from sklearn.metrics import mean_absolute_error
def getMEA(model, X_train, X_test, y_train, y_test):
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    y_pred = y_pred.round().astype(int)
    return mean_absolute_error(y_test, y_pred)

# %%
from sklearn.linear_model import LinearRegression
model1 = LinearRegression()
print("MEA Random Fores:", getMEA(model1, X_train, X_test, y_train, y_test))
# Out:
# MEA Random Fores: 1.5454545454545454

# %%
from sklearn.svm import SVR
model2 = SVR(kernel='rbf')
print("MEA Random Fores:", getMEA(model2, X_train, X_test, y_train, y_test))
# Out:
# MEA Random Fores: 1.5

# %%
from sklearn.tree import DecisionTreeRegressor
model3 = DecisionTreeRegressor()
print("MEA Random Fores:", getMEA(model3, X_train, X_test, y_train, y_test))
# Out:
# MEA Random Fores: 2.062200956937799

# %%
from sklearn.ensemble import RandomForestRegressor
model4 = RandomForestRegressor(random_state=0)
print("MEA Random Fores:", getMEA(model4, X_train, X_test, y_train, y_test))
# Out:
# MEA Random Fores: 1.5227272727272727
