# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('in-vehicle-coupon-recommendation.csv')
df.head()
# Out:
#        destination  passanger weather  temperature  time
# 0  No Urgent Place      Alone   Sunny           55   2PM  \
# 1  No Urgent Place  Friend(s)   Sunny           80  10AM
# 2  No Urgent Place  Friend(s)   Sunny           80  10AM
# 3  No Urgent Place  Friend(s)   Sunny           80   2PM
# 4  No Urgent Place  Friend(s)   Sunny           80   2PM
#
#                   coupon expiration  gender age      maritalStatus  ...
# 0        Restaurant(<20)         1d  Female  21  Unmarried partner  ...  \
# 1           Coffee House         2h  Female  21  Unmarried partner  ...
# 2  Carry out & Take away         2h  Female  21  Unmarried partner  ...
# 3           Coffee House         2h  Female  21  Unmarried partner  ...
# 4           Coffee House         1d  Female  21  Unmarried partner  ...
#
#    CoffeeHouse CarryAway RestaurantLessThan20 Restaurant20To50
# 0        never       NaN                  4~8              1~3  \
# 1        never       NaN                  4~8              1~3
# 2        never       NaN                  4~8              1~3
# 3        never       NaN                  4~8              1~3
# 4        never       NaN                  4~8              1~3
#
#   toCoupon_GEQ5min toCoupon_GEQ15min toCoupon_GEQ25min direction_same
# 0                1                 0                 0              0  \
# 1                1                 0                 0              0
# 2                1                 1                 0              0
# 3                1                 1                 0              0
# 4                1                 1                 0              0
#
#   direction_opp  Y
# 0             1  1
# 1             1  0
# 2             1  1
# 3             1  0
# 4             1  0
#
# [5 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12684 entries, 0 to 12683
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   destination           12684 non-null  object
#  1   passanger             12684 non-null  object
#  2   weather               12684 non-null  object
#  3   temperature           12684 non-null  int64
#  4   time                  12684 non-null  object
#  5   coupon                12684 non-null  object
#  6   expiration            12684 non-null  object
#  7   gender                12684 non-null  object
#  8   age                   12684 non-null  object
#  9   maritalStatus         12684 non-null  object
#  10  has_children          12684 non-null  int64
#  11  education             12684 non-null  object
#  12  occupation            12684 non-null  object
#  13  income                12684 non-null  object
#  14  car                   108 non-null    object
#  15  Bar                   12577 non-null  object
#  16  CoffeeHouse           12467 non-null  object
#  17  CarryAway             12533 non-null  object
#  18  RestaurantLessThan20  12554 non-null  object
#  19  Restaurant20To50      12495 non-null  object
#  20  toCoupon_GEQ5min      12684 non-null  int64
#  21  toCoupon_GEQ15min     12684 non-null  int64
#  22  toCoupon_GEQ25min     12684 non-null  int64
#  23  direction_same        12684 non-null  int64
#  24  direction_opp         12684 non-null  int64
#  25  Y                     12684 non-null  int64
# dtypes: int64(8), object(18)
# memory usage: 2.5+ MB

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# car                     12576
# CoffeeHouse               217
# Restaurant20To50          189
# CarryAway                 151
# RestaurantLessThan20      130
# Bar                       107
# destination                 0
# passanger                   0
# direction_opp               0
# direction_same              0
# toCoupon_GEQ25min           0
# toCoupon_GEQ15min           0
# toCoupon_GEQ5min            0
# income                      0
# occupation                  0
# education                   0
# has_children                0
# maritalStatus               0
# age                         0
# gender                      0
# expiration                  0
# coupon                      0
# time                        0
# temperature                 0
# weather                     0
# Y                           0
# dtype: int64

# %%
df = df.drop('car', axis=1)
df.dropna(inplace=True)

# %%
cate_cols = df.select_dtypes(include='object').columns.tolist()
num_cols = df.select_dtypes(include=['int64', 'float64']).columns.tolist()

# %%
df[cate_cols].nunique()
# Out:
# destination              3
# passanger                4
# weather                  3
# time                     5
# coupon                   5
# expiration               2
# gender                   2
# age                      8
# maritalStatus            5
# education                6
# occupation              25
# income                   9
# Bar                      5
# CoffeeHouse              5
# CarryAway                5
# RestaurantLessThan20     5
# Restaurant20To50         5
# dtype: int64

# %%
df[cate_cols].describe().T
# Out:
#                       count unique                       top  freq
# destination           12079      3           No Urgent Place  5970
# passanger             12079      4                     Alone  6969
# weather               12079      3                     Sunny  9601
# time                  12079      5                       6PM  3078
# coupon                12079      5              Coffee House  3816
# expiration            12079      2                        1d  6760
# gender                12079      2                    Female  6199
# age                   12079      8                        21  2537
# maritalStatus         12079      5           Married partner  4831
# education             12079      6  Some college - no degree  4219
# occupation            12079     25                Unemployed  1814
# income                12079      9           $25000 - $37499  1919
# Bar                   12079      5                     never  4934
# CoffeeHouse           12079      5                     less1  3298
# CarryAway             12079      5                       1~3  4502
# RestaurantLessThan20  12079      5                       1~3  5163
# Restaurant20To50      12079      5                     less1  5859

# %%
for col in cate_cols:
    if col != 'occupation':
        plt.figure(figsize=(18, 6))
        sns.countplot(df, x=col)
        plt.show()

# %%
num_cols.remove('Y')
sns.heatmap(df[num_cols].corr() > 0.7, annot=True)
plt.show()
